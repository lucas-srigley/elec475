# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ELEC475_Lab_3
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ELEC475_Lab_3

# %%
# !python train_all.py
# Out:
# ...
# AUTOMATED TRAINING FOR ALL 3 MODELS
# ...
# This will train 3 models sequentially:
#   1. Without distillation (baseline)
#   2. Response-based knowledge distillation
#   3. Feature-based knowledge distillation
#
# This may take a long time depending on your hardware.
# You can also train models individually by editing train.py
# ...
#
# Continue with automated training? (y/n): y
#
# ...
# TRAINING: Model WITHOUT Distillation (Baseline)
# ...
# ✓ Modified train.py to use distillation_method = 'none'
#
# Using device: cpu
# Train dataset size: 1464
# Val dataset size: 1449
#
# Loading teacher model (FCN-ResNet50)...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# !python test.py
# Out:
# Using device: cuda
#
# ...
# Step 2.1: Testing Pretrained FCN-ResNet50
# ...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FCN_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=FCN_ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Val dataset size: 1449
# Testing FCN-ResNet50: 100% 182/182 [00:37<00:00,  4.89it/s]
#
# FCN-ResNet50 Results:
#   Mean IoU: 0.6534
#   Inference time: 15.67 ms/image
#   Total parameters: 35,322,218
#
# ...
# Testing Without Distillation Model: best_model_none.pth
# ...
